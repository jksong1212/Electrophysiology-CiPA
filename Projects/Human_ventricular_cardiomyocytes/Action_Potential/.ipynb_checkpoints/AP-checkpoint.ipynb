# %%
import os, sys, time, copy
import numpy as np
import matplotlib.pyplot as plt

import myokit
sys.path.append('../../../')
sys.path.append('../../../Protocols')
sys.path.append('../../../Models')
sys.path.append('../../../Lib')
import protocol_lib
import mod_trace

# %%
def create_folder(path):
    if not os.path.exists(path):
        os.makedirs(path)
        print('"%s" has been created.'%(path))
    else:
        print("The folder already exists.")

# %%
result_dir = './Results'
create_folder(result_dir)
# Out:
# The folder already exists.

# %%
class IonModel:
    def __init__(self, name=None, mmt=None, log=None, params=None):        
        super().__init__()
        
        self.name = name
        self.mmt = mmt
        self.log = log
        self.params = params
    
        self.apd = {
            90: 0,
        }    
        
    def __new__(cls, name=None, mmt=None, log=None, params=None):        
        return super().__new__(cls)

# %%
'''
Human Ventricular Cardiomyocytes
'''
import argparse

parser = argparse.ArgumentParser(description='Human Ventricular Cardiomyocytes.')
# parser.add_argument('--epochs',        required=False, default=300,  type=int)
# parser.add_argument('--batch_size',    required=False, default=train_pars.batch_size,  type=int,    help='BATCH SIZE')
# parser.add_argument('--patience',      required=False, default=1000, type=int,    help='patience')
# parser.add_argument('--num_workers',   required=False, default=8,    type=int,    help='num_workers')
# args = parser.parse_args()
args, _ = parser.parse_known_args()
args.mmt_dir_path = "../../../mmt-model-files"
args.cell_types = ['Endocardial', 'Epicardial', 'Mid-myocardial']
args.end_time = 500
args.bcl = 2000
args.duration = 0.5
args.offset = 20

models = {}
models['tenTusscher2004'] = IonModel('tenTusscher2004', "tentusscher-2004.mmt")
models['tenTusscher2004'].log = ["ina.INa", "ito.Ito", "ical.ICaL", "ikr.IKr", "iks.IKs", "ik1.IK1" ]

models['tenTusscher2006'] = IonModel('tenTusscher2006', "tentusscher-2006.mmt")
models['tenTusscher2006'].log = ["ina.INa", "ito.Ito", "ical.ICaL", "ikr.IKr", "iks.IKs", "ik1.IK1" ]

models['ORD2011'] = IonModel('ORD2011', "ord-2011.mmt")
models['ORD2011'].log = ["ina.INa", "ito.Ito", "ical.ICaL", "ikr.IKr", "iks.IKs", "ik1.IK1", "inal.INaL" ]

models['ORD2017'] = IonModel('ORD2017', "newordherg_qNet-v1.mmt")
models['ORD2017'].log = ["ina.INa", "ito.Ito", "ical.ICaL", "ikr.IKr", "iks.IKs", "ik1.IK1", "inal.INaL" ]

# %%
import simulator_myokit
'''
Simulation with Myokit
'''
start_time = time.time()

protocol = myokit.pacing.blocktrain(args.bcl*100, args.duration, offset=args.offset) # period, duration, offset=0, level=1.0, limit=0

for model_name, m in models.items():      
    start = time.time()
    
    m_myokit, _, _ = myokit.load(os.path.join(args.mmt_dir_path, m.mmt))
    s_myokit = simulator_myokit.Simulator(m_myokit, protocol, max_step=0.5, abs_tol=1e-08, rel_tol=1e-10, vhold=0)  # 1e-12, 1e-14  # 1e-08, 1e-10
    m.model = m_myokit
    m.sim = s_myokit
    
    print(f"{model_name} --- %s seconds ---"%(time.time()-start))

print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# tenTusscher2004 --- 2.36726713180542 seconds ---
# tenTusscher2006 --- 2.5855400562286377 seconds ---
# ORD2011 --- 3.164360523223877 seconds ---
# ORD2017 --- 3.796797275543213 seconds ---
# --- 11.922672986984253 seconds ---

# %%
'''
params for models
'''
cell_typeNo = 0

models['tenTusscher2004'].params = {
    'cell.type': cell_typeNo,        
}
models['tenTusscher2006'].params = {
    'cell.type': cell_typeNo,        
}
models['ORD2011'].params = {
    'cell.mode': cell_typeNo,        
}
models['ORD2017'].params = {
    'cell.mode': cell_typeNo,        
}

# %%
start_time = time.time()

for model_name, m in models.items():
    print(model_name)
    
    m.sim.set_simulation_params(m.params)    
    # Pre-pace and set a threshold value for APD measurements
    y0 = m.sim.pre_simulate(args.bcl*100, sim_type=1)    
    # simulation
    d = m.sim.simulate(args.end_time, log_times=None, extra_log=m.log)
    
    # APD
    vt = 0.5 * m.sim.simulation.state()[m.model.get('membrane.V').indice()]        
    apds = d.apd(threshold=vt, v='membrane.V')            
    m.apd[50] = {
        'start': apds['start'][0],
        'duration': apds['duration'][0],
        'vt': vt,      
    }    
    print(f'APD50 for {model_name} = ' + str(apds['duration'][0]) + ' [ms]')
    
    
    # s.pre(bcl * 30)
    # d2, apds = d = info['sim'].simulation.run(end_time, apd_variable='membrane.V', apd_threshold=vt)
    # start2 = apds['start'][0]
    # duration2 = apds['duration'][0]
    # print('(Method 2) APD = ' + str(duration2) + ' [ms]')
    
    
    vt = 0.9 * m.sim.simulation.state()[m.model.get('membrane.V').indice()]        
    apds = d.apd(threshold=vt, v='membrane.V')        
    m.apd[90] = {
        'start': apds['start'][0],
        'duration': apds['duration'][0],        
        'vt': vt
    }        
    print(f'APD90 for {model_name} = ' + str(apds['duration'][0]) + ' [ms]')
    
    
    m.time = d['engine.time']
    m.V = d['membrane.V']
    m.I = {}
    for l in m.log:
        m.I[l.split('.')[1]] = d[l]
            
    print("-"*100)
print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# tenTusscher2004
# APD50 for tenTusscher2004 = 299.30733114929444 [ms]
# APD90 for tenTusscher2004 = 319.099035589596 [ms]
# ----------------------------------------------------------------------------------------------------
# tenTusscher2006
# APD50 for tenTusscher2006 = 294.32152993158263 [ms]
# APD90 for tenTusscher2006 = 311.63965304781095 [ms]
# ----------------------------------------------------------------------------------------------------
# ORD2011
# APD50 for ORD2011 = 284.74708847070576 [ms]
# APD90 for ORD2011 = 322.5241244062398 [ms]
# ----------------------------------------------------------------------------------------------------
# ORD2017
# APD50 for ORD2017 = 295.9696155174848 [ms]
# APD90 for ORD2017 = 323.3608467440827 [ms]
# ----------------------------------------------------------------------------------------------------
# --- 0.5214650630950928 seconds ---

# %%
'''
Plot
'''
start_time = time.time()

fig, ax = plt.subplots(1,1, figsize=(16,8))    
for model_name, m in models.items():
    print(model_name)        
    # fig.suptitle(sim_ohara2017.name, fontsize=14)
    ax.set_title(args.cell_types[cell_typeNo], fontsize=24)
    # ax.set_xlim(bdf_m.times.min(), bdf_m.times.max())
    # ax.set_ylim(ylim[0], ylim[1])
    ax.set_ylabel('Membrane Potential (mV)', fontsize=18)  
    ax.set_xlabel('Time (ms)', fontsize=18)       

    ax.plot( m.time, m.V, label=model_name, linewidth=3)         
    # textstr = "GNa : %1.4f\nGNaL : %1.4f\nGto : %1.4f\nPCa : %1.4f\nGKr : %1.4f\nGKs : %1.4f\nGK1 : %1.4f\nGf : %1.4f"%(GNa/g_fc[0], \
    #             GNaL/g_fc[1], Gto/g_fc[2], PCa/g_fc[3], GKr/g_fc[4], GKs/g_fc[5], GK1/g_fc[6], Gf/g_fc[7])
    # props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    # place a text box in upper left in axes coords
    #     ax.text(0.67, 0.60, textstr, transform=ax.transAxes, fontsize=14, verticalalignment='top', bbox=props)    
    #     fig1 = plt.gcf()
    ax.legend(fontsize=18)
    ax.grid()

plt.show()
fig.savefig(os.path.join(result_dir, f"AP-{args.cell_types[cell_typeNo]}.jpg"), dpi=300)    
print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# tenTusscher2004
# tenTusscher2006
# ORD2011
# ORD2017
# --- 0.7477238178253174 seconds ---

# %%
'''
Plot
'''
start_time = time.time()

fig, ax = plt.subplots(8,1, figsize=(16, 80))    
ax[0].plot( np.zeros(args.end_time), linewidth=1, color='k')      
# fig.suptitle(f"{model_name}-{cell_types[cell_typeNo]}", fontsize=20)
for model_name, m in models.items():
    # print(model_name)                    
    # ax[0].set_title(f"{model_name}-{cell_types[cell_typeNo]}", fontsize=20)
    # ax.set_xlim(bdf_m.times.min(), bdf_m.times.max())
    # ax.set_ylim(ylim[0], ylim[1])
    ax[0].set_ylabel('Membrane Potential (mV)', fontsize=18)  
    ax[0].set_xlabel('Time (ms)', fontsize=18)       

    ax[0].plot( m.time, m.V, label=model_name, linewidth=2)      
    
   
    # textstr = "GNa : %1.4f\nGNaL : %1.4f\nGto : %1.4f\nPCa : %1.4f\nGKr : %1.4f\nGKs : %1.4f\nGK1 : %1.4f\nGf : %1.4f"%(GNa/g_fc[0], \
    #             GNaL/g_fc[1], Gto/g_fc[2], PCa/g_fc[3], GKr/g_fc[4], GKs/g_fc[5], GK1/g_fc[6], Gf/g_fc[7])
    # props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    # place a text box in upper left in axes coords
    #     ax.text(0.67, 0.60, textstr, transform=ax.transAxes, fontsize=14, verticalalignment='top', bbox=props)    
    #     fig1 = plt.gcf()
    ax[0].legend(fontsize=18)
    ax[0].grid()
    
    for i, [ion_name, Iion] in enumerate(m.I.items()):
        # ax[i+1].set_title(f"{model_name}-{cell_types[cell_typeNo]}", fontsize=20)
        # ax.set_xlim(bdf_m.times.min(), bdf_m.times.max())
        # ax.set_ylim(ylim[0], ylim[1])
        
        ax[i+1].set_ylabel(f"{ion_name} (pA/pF)", fontsize=18)  
        ax[i+1].set_xlabel('Time (ms)', fontsize=18)       
        ax[i+1].plot( m.time, Iion, label=model_name, linewidth=2)         
        # textstr = "GNa : %1.4f\nGNaL : %1.4f\nGto : %1.4f\nPCa : %1.4f\nGKr : %1.4f\nGKs : %1.4f\nGK1 : %1.4f\nGf : %1.4f"%(GNa/g_fc[0], \
        #             GNaL/g_fc[1], Gto/g_fc[2], PCa/g_fc[3], GKr/g_fc[4], GKs/g_fc[5], GK1/g_fc[6], Gf/g_fc[7])
        # props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
        # place a text box in upper left in axes coords
        #     ax.text(0.67, 0.60, textstr, transform=ax.transAxes, fontsize=14, verticalalignment='top', bbox=props)    
        #     fig1 = plt.gcf()
        ax[i+1].legend(fontsize=18)
        ax[i+1].grid()
        
plt.show()
fig.savefig(os.path.join(result_dir, f"{model_name}-{args.cell_types[cell_typeNo]}.jpg"), dpi=300)    

print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# --- 6.263688564300537 seconds ---

# %%
'''
Plot
'''
start_time = time.time()

for model_name, m in models.items():
    print(model_name)        
    apd50 = m.apd[50]
    apd90 = m.apd[90]
    fig, ax = plt.subplots(1,1, figsize=(12,8))    
    # fig.suptitle(sim_ohara2017.name, fontsize=14)
    ax.set_title(f"{model_name}-{args.cell_types[cell_typeNo]}", fontsize=20)
    # ax.set_xlim(bdf_m.times.min(), bdf_m.times.max())
    # ax.set_ylim(ylim[0], ylim[1])
    ax.set_ylabel('Membrane Potential (mV)', fontsize=18)  
    ax.set_xlabel('Time (ms)', fontsize=18)       

    ax.plot( m.time, m.V, label=model_name, linewidth=3, color='k')      
    ax.arrow(apd50['start'], apd50['vt'], apd50['duration'], 0, head_width=5, head_length=10, length_includes_head=True)
    ax.text(apd50['start']+40, -40, str(apd50['duration']), fontsize=18)
    ax.arrow(apd90['start'], apd90['vt'], apd90['duration'], 0, head_width=5, head_length=10, length_includes_head=True)
    ax.text(apd90['start']+40, -75, str(apd90['duration']), fontsize=18)
    # textstr = "GNa : %1.4f\nGNaL : %1.4f\nGto : %1.4f\nPCa : %1.4f\nGKr : %1.4f\nGKs : %1.4f\nGK1 : %1.4f\nGf : %1.4f"%(GNa/g_fc[0], \
    #             GNaL/g_fc[1], Gto/g_fc[2], PCa/g_fc[3], GKr/g_fc[4], GKs/g_fc[5], GK1/g_fc[6], Gf/g_fc[7])
    # props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    # place a text box in upper left in axes coords
    #     ax.text(0.67, 0.60, textstr, transform=ax.transAxes, fontsize=14, verticalalignment='top', bbox=props)    
    #     fig1 = plt.gcf()
    ax.legend(fontsize=18)
    ax.grid()
    plt.show()
    fig.savefig(os.path.join(result_dir, f"{model_name}-{args.cell_types[cell_typeNo]}-APD.jpg"), dpi=300)    
    print('-'*100)
print("--- %s seconds ---"%(time.time()-start_time))
# Out:
# tenTusscher2004
# ----------------------------------------------------------------------------------------------------
# tenTusscher2006
# ----------------------------------------------------------------------------------------------------
# ORD2011
# ----------------------------------------------------------------------------------------------------
# ORD2017
# ----------------------------------------------------------------------------------------------------
# --- 2.1317641735076904 seconds ---

# %%
print("Complete")
